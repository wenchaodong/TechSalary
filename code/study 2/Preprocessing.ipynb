# %% [markdown]
# # import packages and define functions

# %%
import pandas as pd 
import numpy as np
import re
import gensim.corpora as corpora
from scipy import stats
from langdetect import detect
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import collections
from collections import Counter
import spacy
import math
from lexicalrichness import LexicalRichness
en_core = spacy.load('en_core_web_sm')

# %% [markdown]
# # Define functions

# %%
def clean(text):
    text = text.lower() ## lowercase
    text = ''.join([char for char in text if char in 'abcdefghijklmnopqrstuvwxyz ']) ## remove punctuations etc.
    text = ' '.join(text.split())## remove multiple spaces
    return text

def multiple_replace(string):
    rep_dict = {"google":"it", "amazon":"it", "microsoft":"it", "facebook":"it", "apple":"it", "oracle":"it", "salesforce":"it", "intel":"it", "cisco":"it", "uber":"it", "capital one":"it", "ibm":"it", "linkedin":"it"}
    pattern = re.compile("|".join([re.escape(k) for k in sorted(rep_dict,key=len,reverse=True)]), flags=re.DOTALL)
    return pattern.sub(lambda x: rep_dict[x.group(0)], string)

def lemmatized_words_num(text):
    lex = LexicalRichness(text)
    return lex.words

def entropy(bow, prob_dict):
    return sum([-v*math.log2(v)*bow[k] for k, v in prob_dict.items()])

# %% [markdown]
# # Load reviews

# %%
CS_Reviews_Final = pd.read_csv('CS_Reviews_Final.csv').copy().drop(['Unnamed: 0'], axis=1)
CS_Reviews_Final
# Out:
#                                                   title  \
# 0                                             Dream job
# 1     Worked as a contractor software engineer, work...
# 2                          Productive and fun workplace
# 3                            Great company to work for!
# 4                                        Best Workplace
# ...                                                 ...
# 7056                                                Ibm
# 7057                                            5 stars
# 7058                                      Great company
# 7059            Great WLB, pay and technical challenges
# 7060                  Best company I've ever worked for
#
#                                                status  \
# 0                 Software Engineer(Current Employee)
# 1       Software Engineer Contractor(Former Employee)
# 2                  Software Engineer(Former Employee)
# 3      Quality Assurance Specialist(Current Employee)
# 4                 Software Engineer(Current Employee)
# ...                                               ...
# 7056             Delivery Architect(Current Employee)
# 7057  Sr. Technical Program Manager(Current Employee)
# 7058              Software Engineer(Current Employee)
# 7059              Software Engineer(Current Employee)
# 7060         Staff Software Engineer(Former Employee)
#
#                                                    pros  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7056                                                NaN
# 7057                                                NaN
# 7058                                                NaN
# 7059                                                NaN
# 7060  Excellent culture. Free food. Great coffee and...
#
#                                           cons  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 7056                                       NaN
# 7057                                       NaN
# 7058                                       NaN
# 7059                                       NaN
# 7060  Work could be less challenging at times.
#
#                                                  review  rating
# 0     This is one of the best place to work in the w...     5.0
# 1     Worked as a contractor software engineer, work...     5.0
# 2     It was a fun and interesting experience. Lots ...     5.0
# 3     One of the best companies to work for overall....     5.0
# 4     Google is a great work place. They pay well an...     5.0
# ...                                                 ...     ...
# 7056  I’ve been with IBM for many years of my career...     1.0
# 7057  What is the best part of working at the compan...     5.0
# 7058  LinkedIn's food is great. There is a InDay eve...     5.0
# 7059  Great pay, tons of time off.Food is top notch,...     5.0
# 7060  I got to work with talented and passionate col...     5.0
#
# [7061 rows x 6 columns]

# %% [markdown]
# # Preprocessing reviews

# %%
CS_Reviews_Final['processed_review'] = CS_Reviews_Final['review'].apply(clean)
CS_Reviews_Final["processed_review"] = CS_Reviews_Final["processed_review"].apply(multiple_replace)

# %% [markdown]
# ## lemmatize

# %%
stop = stopwords.words('english')
CS_Reviews_Final['wo_stop'] = CS_Reviews_Final['processed_review'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
CS_Reviews_Final["lemmatized"] = CS_Reviews_Final['wo_stop'].apply(lambda x: " ".join([y.lemma_ for y in en_core(x)]))

# %%
CS_Reviews_Final['total_word_num'] = CS_Reviews_Final['lemmatized'].apply(lemmatized_words_num)
CS_Reviews_Final['raw_word_count'] = CS_Reviews_Final['processed_review'].apply(lambda text: len(text.split()))
CS_Reviews_Final = CS_Reviews_Final.loc[(CS_Reviews_Final['total_word_num'] != 0)]
CS_Reviews_Final
# Out:
#                                                   title  \
# 0                                             Dream job
# 1     Worked as a contractor software engineer, work...
# 2                          Productive and fun workplace
# 3                            Great company to work for!
# 4                                        Best Workplace
# ...                                                 ...
# 7056                                                Ibm
# 7057                                            5 stars
# 7058                                      Great company
# 7059            Great WLB, pay and technical challenges
# 7060                  Best company I've ever worked for
#
#                                                status  \
# 0                 Software Engineer(Current Employee)
# 1       Software Engineer Contractor(Former Employee)
# 2                  Software Engineer(Former Employee)
# 3      Quality Assurance Specialist(Current Employee)
# 4                 Software Engineer(Current Employee)
# ...                                               ...
# 7056             Delivery Architect(Current Employee)
# 7057  Sr. Technical Program Manager(Current Employee)
# 7058              Software Engineer(Current Employee)
# 7059              Software Engineer(Current Employee)
# 7060         Staff Software Engineer(Former Employee)
#
#                                                    pros  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7056                                                NaN
# 7057                                                NaN
# 7058                                                NaN
# 7059                                                NaN
# 7060  Excellent culture. Free food. Great coffee and...
#
#                                           cons  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 7056                                       NaN
# 7057                                       NaN
# 7058                                       NaN
# 7059                                       NaN
# 7060  Work could be less challenging at times.
#
#                                                  review  rating  \
# 0     This is one of the best place to work in the w...     5.0
# 1     Worked as a contractor software engineer, work...     5.0
# 2     It was a fun and interesting experience. Lots ...     5.0
# 3     One of the best companies to work for overall....     5.0
# 4     Google is a great work place. They pay well an...     5.0
# ...                                                 ...     ...
# 7056  I’ve been with IBM for many years of my career...     1.0
# 7057  What is the best part of working at the compan...     5.0
# 7058  LinkedIn's food is great. There is a InDay eve...     5.0
# 7059  Great pay, tons of time off.Food is top notch,...     5.0
# 7060  I got to work with talented and passionate col...     5.0
#
#                                        processed_review  \
# 0     this is one of the best place to work in the w...
# 1     worked as a contractor software engineer work ...
# 2     it was a fun and interesting experience lots o...
# 3     one of the best companies to work for overall ...
# 4     it is a great work place they pay well and res...
# ...                                                 ...
# 7056  ive been with it for many years of my career i...
# 7057  what is the best part of working at the compan...
# 7058  its food is great there is a inday every month...
# 7059  great pay tons of time offfood is top notch pr...
# 7060  i got to work with talented and passionate col...
#
#                                                 wo_stop  \
# 0     one best place work world couldnt ask culture ...
# 1     worked contractor software engineer work time ...
# 2     fun interesting experience lots handson truly ...
# 3     one best companies work overall stable company...
# 4     great work place pay well respect employees te...
# ...                                                 ...
# 7056  ive many years career facet every step done la...
# 7057  best part working companythe culturewhat stres...
# 7058  food great inday every month lot learn culture...
# 7059  great pay tons time offfood top notch probably...
# 7060  got work talented passionate colleagues valued...
#
#                                              lemmatized  total_word_num  \
# 0     one good place work world could not ask cultur...              19
# 1     work contractor software engineer work time fl...              17
# 2     fun interesting experience lot handson truly l...              13
# 3     one good company work overall stable company p...              16
# 4     great work place pay well respect employee tea...              24
# ...                                                 ...             ...
# 7056  I ve many year career facet every step do layo...              27
# 7057  good part work companythe culturewhat stressfu...              17
# 7058  food great inday every month lot learn culture...              13
# 7059  great pay ton time offfood top notch probably ...              22
# 7060  get work talented passionate colleague value e...              22
#
#       raw_word_count
# 0                 34
# 1                 26
# 2                 29
# 3                 32
# 4                 51
# ...              ...
# 7056              58
# 7057              34
# 7058              30
# 7059              31
# 7060              38
#
# [7061 rows x 11 columns]

# %% [markdown]
# # Entropy

# %% [markdown]
# ## Get Global probability

# %%
total_word_collection = ' '.join(CS_Reviews_Final.lemmatized.to_list())
word_tokenize_total_word = word_tokenize(total_word_collection)
len_tok = len(word_tokenize_total_word)
total_word_Counter = Counter(word_tokenize_total_word)
global_key_mapping = {k:v/len_tok for k,v in total_word_Counter.items()}
global_key_mapping
# Out:
# {'one': 0.003810371843722716,
#  'good': 0.018837923318434913,
#  'place': 0.009627115508039942,
#  'work': 0.045435359556863585,
#  'world': 0.0010060769359753453,
#  'could': 0.0017346154068540436,
#  'not': 0.005712666739905984,
#  'ask': 0.0006186794951112756,
#  'culture': 0.00634291033772962,
#  'amazing': 0.001347217965989974,
#  'benefit': 0.004197769284586786,
#  'unbeatable': 1.1564102712360291e-05,
#  'well': 0.004729718009355359,
#  'that': 0.0004278718003573308,
#  's': 0.0009771666791944446,
#  'I': 0.0018444743826214664,
#  'm': 0.00046834615985059177,
#  'bless': 2.8910256780900728e-05,
#  'contractor': 0.0014859871985382974,
#  'software': 0.002422679518239481,
#  'engineer': 0.0020815384882248524,
#  'time': 0.007620743687445432,
#  'flexibility': 0.0006013333410427352,
#  'great': 0.015495897634562791,
#  'worker': 0.0008788718061393822,
#  'empowerment': 1.1564102712360291e-05,
#  'low': 0.0009656025764820843,
#  'treat': 0.0008383974466461211,
#  'secondclass': 1.1564102712360291e-05,
#  'citizen': 4.6256410849441164e-05,
#  'within': 0.0011853205280169298,
#  'fun': 0.002578794904856345,
#  'interesting': 0.0011564102712360292,
#  'experience': 0.004851141087835142,
#  'lot': 0.008488051390872454,
#  'handson': 6.360256491798161e-05,
#  'truly': 0.00045100000578205134,
#  'learn': 0.009644461662108483,
#  'invaluable': 4.047435949326102e-05,
#  'team': 0.01146580783930523,
#  'grow': 0.0018791666907585474,
#  'company': 0.014963948909794217,
#  'overall': 0.0018560384853338267,
#  'stable': 0.00022550000289102567,
#  'provide': 0.0024284615695956612,
#  'opportunity': 0.004943653909534025,
#  'career': 0.0031974743999676207,
#  'advancement': 0.0011737564253045695,
#  'help': 0.0030760513214878374,
#  'succeed': 0.000318012824589908,
#  'role': 0.0010812436036056873,
#  'pay': 0.0030066667052136755,
#  'respect': 0.0005377307761247536,
#  'employee': 0.006273525721455458,
#  'change': 0.002700217983336128,
#  'flexible': 0.001312525657852893,
#  'manager': 0.005406218018028436,
#  'stop': 0.00017346154068540438,
#  'move': 0.0018155641258405658,
#  'tenure': 0.00015611538661686392,
#  'current': 0.000595551289686555,
#  'year': 0.004666115444437378,
#  'make': 0.004446397492902532,
#  'impact': 0.0005030384679876726,
#  'interest': 0.000318012824589908,
#  'benifit': 4.047435949326102e-05,
#  'plenty': 0.000514602570700033,
#  'vacation': 0.000277538465096647,
#  'office': 0.0012257948875101909,
#  'space': 0.0003064487218775477,
#  'get': 0.007863589844404998,
#  'promotion': 0.0006071153923989153,
#  'difficult': 0.0010407692441124262,
#  'due': 0.0009366923197011835,
#  'need': 0.003058705167419297,
#  'community': 0.00023706410560338597,
#  'contribution': 0.00016189743797304407,
#  'do': 0.004457961595614892,
#  'high': 0.001908076947539448,
#  'profile': 5.203846220562131e-05,
#  'really': 0.003486576967776628,
#  'colleague': 0.000832615395289941,
#  'smart': 0.0014744230958259371,
#  'people': 0.009812141151437708,
#  'satisfaction': 0.00025441025967192643,
#  'use': 0.0028332051645282713,
#  'million': 9.829487305506248e-05,
#  'around': 0.001468641044469757,
#  'fairly': 0.00022550000289102567,
#  'long': 0.0023301666965405985,
#  'termive': 5.7820513561801455e-06,
#  'enjoy': 0.0026423974697743265,
#  'compilation': 5.7820513561801455e-06,
#  'nowif': 5.7820513561801455e-06,
#  'would': 0.0035559615840507893,
#  'wish': 0.0003006666705213676,
#  'take': 0.002740692342829389,
#  'another': 0.000676500008673077,
#  'path': 0.00027175641374046686,
#  'choose': 0.00024284615695956612,
#  'enable': 0.0001792435920415845,
#  'inclusive': 0.00015611538661686392,
#  'give': 0.0022781282343349776,
#  'life': 0.0037930256896541756,
#  'balancelot': 1.7346154068540437e-05,
#  'engagement': 6.938461627416175e-05,
#  'activity': 0.0004220897490011506,
#  'part': 0.004804884676985701,
#  'workplace': 0.00119110257937311,
#  'also': 0.003064487218775477,
#  'covid': 9.251282169888233e-05,
#  'situation': 0.0003006666705213676,
#  'new': 0.006140538540263314,
#  'policy': 0.0004567820571382315,
#  'aspect': 0.00031223077323372784,
#  'comfort': 6.360256491798161e-05,
#  'mental': 7.51666676303419e-05,
#  'physical': 8.673077034270219e-05,
#  'technical': 0.0015727179688809997,
#  'enablement': 1.7346154068540437e-05,
#  'allow': 0.0009887307819068049,
#  'growth': 0.0018097820744843855,
#  'various': 0.0006880641113854373,
#  'dimension': 2.3128205424720582e-05,
#  'apart': 0.00012142307847978306,
#  'core': 0.00022550000289102567,
#  'job': 0.008164256514926365,
#  'nice': 0.002341730799252959,
#  'soooo': 5.7820513561801455e-06,
#  'idea': 0.0007805769330843196,
#  'discuss': 0.00020815384882248524,
#  'freely': 4.047435949326102e-05,
#  'hence': 7.51666676303419e-05,
#  'eager': 4.6256410849441164e-05,
#  'communication': 0.0005088205193438529,
#  'maybe': 0.0001503333352606838,
#  'environment': 0.005475602634302598,
#  'important': 0.0005377307761247536,
#  'thing': 0.0033188974784474036,
#  'helpful': 0.00119110257937311,
#  'member': 0.0009020000115641027,
#  'challenge': 0.0024111154155271207,
#  'project': 0.00475862826613626,
#  'excellent': 0.0017808718177034848,
#  'perk': 0.0007285384708786984,
#  'mode': 3.469230813708087e-05,
#  'package': 0.0002891025678090073,
#  'pursue': 9.829487305506248e-05,
#  'personal': 0.000676500008673077,
#  'right': 0.0009887307819068049,
#  'much': 0.0030818333728440178,
#  'stress': 0.0005261666734123932,
#  'etcwhat': 5.7820513561801455e-06,
#  'else': 0.0004972564166314925,
#  'say': 0.0014512948904012166,
#  'let': 0.0005319487247685734,
#  'hit': 0.00016189743797304407,
#  'character': 6.360256491798161e-05,
#  'minimum': 0.00017346154068540438,
#  'please': 0.00015611538661686392,
#  'bureaucratic': 8.673077034270219e-05,
#  'condescend': 2.3128205424720582e-05,
#  'bright': 0.00020237179746630509,
#  'though': 0.0008383974466461211,
#  'level': 0.0015669359175248196,
#  'prestige': 1.1564102712360291e-05,
#  'tell': 0.0005782051356180146,
#  'someone': 0.0005724230842618345,
#  'cool': 0.00038739744086406974,
#  'code': 0.0011621923225922093,
#  'allot': 1.1564102712360291e-05,
#  'freindly': 1.1564102712360291e-05,
#  'free': 0.0010754615522495072,
#  'lunch': 0.00045100000578205134,
#  'coffee': 0.00016767948932922423,
#  'sometimes': 0.0009598205251259041,
#  'black': 3.469230813708087e-05,
#  'out': 7.51666676303419e-05,
#  'alright': 5.7820513561801455e-05,
#  'sure': 0.0006707179573168969,
#  'computer': 0.000318012824589908,
#  've': 0.001318307709209073,
#  'far': 0.0006418077005359962,
#  'staff': 0.0005839871869741947,
#  'food': 0.0006707179573168969,
#  'snack': 0.00017346154068540438,
#  'program': 0.0006938461627416175,
#  'graduate': 0.0001908076947539448,
#  'college': 0.0004452179544258712,
#  'struggle': 0.00024284615695956612,
#  'money': 0.0005492948788371138,
#  'unable': 5.7820513561801455e-05,
#  'afford': 6.938461627416175e-05,
#  'plate': 5.7820513561801455e-06,
#  'eat': 0.00010407692441124262,
#  'able': 0.0012026666820854704,
#  'keep': 0.0016363205337989813,
#  'energize': 1.7346154068540437e-05,
#  'enhance': 0.00019658974611012496,
#  'ability': 0.0007574487276595991,
#  'back': 0.0012084487334416505,
#  'foot': 9.829487305506248e-05,
#  'go': 0.003133871835049639,
#  'th': 4.6256410849441164e-05,
#  'house': 5.7820513561801455e-05,
#  'support': 0.002590359007568705,
#  'la': 1.1564102712360291e-05,
#  'love': 0.0019138589988956282,
#  'management': 0.008580564212571336,
#  'canteen': 2.8910256780900728e-05,
#  'alot': 0.0001908076947539448,
#  'campuse': 5.7820513561801455e-06,
#  'reliable': 2.3128205424720582e-05,
#  'fair': 0.0002833205164528271,
#  'spend': 0.000716974368166338,
#  'x': 0.00014455128390450364,
#  'tpm': 2.3128205424720582e-05,
#  'brilliant': 0.00018502564339776466,
#  'infrastructure': 0.0002139359001786654,
#  'type': 0.000358487184083169,
#  'outstanding': 0.00016189743797304407,
#  'paybenefit': 1.7346154068540437e-05,
#  'second': 0.00024862820831574625,
#  'none': 0.00010407692441124262,
#  'working': 0.0012547051442910915,
#  'ensure': 0.0002833205164528271,
#  'future': 0.0005203846220562131,
#  'tech': 0.0012951795037843526,
#  'pretty': 0.0009366923197011835,
#  'accessible': 6.360256491798161e-05,
#  'come': 0.0016883589960046024,
#  'costwhilst': 5.7820513561801455e-06,
#  'salary': 0.0010581153981809666,
#  'location': 0.0006418077005359962,
#  'londonwfh': 5.7820513561801455e-06,
#  'model': 0.00027175641374046686,
#  'bit': 0.0005203846220562131,
#  'play': 0.0004220897490011506,
#  'ping': 0.00019658974611012496,
#  'pong': 0.00019658974611012496,
#  'talk': 0.0004914743652753124,
#  'coworker': 0.001867602588046187,
#  'etc': 0.0006996282140977976,
#  'day': 0.0045389103146014145,
#  'visit': 5.7820513561801455e-05,
#  'family': 0.0005839871869741947,
#  'travel': 0.0005203846220562131,
#  'creative': 0.00023706410560338597,
#  'alone': 8.673077034270219e-05,
#  'know': 0.0017577436122787643,
#  'brand': 0.00017346154068540438,
#  'tool': 0.0011217179630989482,
#  'listen': 0.00017346154068540438,
#  'foresee': 5.7820513561801455e-06,
#  'socialise': 5.7820513561801455e-06,
#  'communicate': 0.00019658974611012496,
#  'brake': 1.1564102712360291e-05,
#  'feedback': 0.0002833205164528271,
#  'gratitude': 1.1564102712360291e-05,
#  'question': 0.00032379487594608815,
#  'answer': 0.00023706410560338597,
#  'newbie': 1.1564102712360291e-05,
#  'start': 0.001902294896183268,
#  'suggest': 7.51666676303419e-05,
#  'trze': 5.7820513561801455e-06,
#  'directly': 0.00013298718119214334,
#  'depend': 0.0013761282227708746,
#  'effort': 0.00046834615985059177,
#  'put': 0.000832615395289941,
#  'result': 0.0008152692412214006,
#  'produce': 0.00023128205424720582,
#  'always': 0.002896807729446253,
#  'toe': 4.6256410849441164e-05,
#  'continue': 0.0004567820571382315,
#  'towards': 0.0003411410300146286,
#  'challenging': 0.00038739744086406974,
#  'goal': 0.000913564114276463,
#  'teamwork': 0.0001908076947539448,
#  'you': 0.00158428207159336,
#  're': 0.001266269247003452,
#  'improve': 0.0009077820629202829,
#  'yourslef': 5.7820513561801455e-06,
#  'business': 0.002098884642293393,
#  'perspective': 9.829487305506248e-05,
#  'employer': 0.00031223077323372784,
#  'programmer': 0.00020237179746630509,
#  'compensate': 0.00018502564339776466,
#  'find': 0.0019485513070327091,
#  'fit': 0.0003064487218775477,
#  'kind': 0.0004394359030696911,
#  'seem': 0.0012084487334416505,
#  'actually': 0.0005030384679876726,
#  'care': 0.0016941410473607827,
#  'person': 0.0006244615464674557,
#  'however': 0.0016594487392237018,
#  'slowly': 0.00014455128390450364,
#  'away': 0.00039896154357643005,
#  'stand': 0.00027175641374046686,
#  'value': 0.0010754615522495072,
#  'individual': 0.0007979230871528601,
#  'traditional': 0.00010985897576742277,
#  'profitdriven': 5.7820513561801455e-06,
#  'personally': 0.0001908076947539448,
#  'feel': 0.0019485513070327091,
#  'like': 0.00477019236884862,
#  'sleep': 1.7346154068540437e-05,
#  'night': 0.00024862820831574625,
#  'atmosphere': 0.0005492948788371138,
#  'issue': 0.0016421025851551614,
#  'up': 0.00010407692441124262,
#  'fill': 0.00021971795153484554,
#  'see': 0.0013645641200585143,
#  'other': 0.0009020000115641027,
#  'think': 0.0012142307847978306,
#  'excited': 5.203846220562131e-05,
#  'every': 0.002301256439759698,
#  'they': 0.00031223077323372784,
#  'look': 0.0014455128390450365,
#  'recommend': 0.001150628219879849,
#  'anyone': 0.000514602570700033,
#  'exceptional': 0.00013298718119214334,
#  'wlb': 9.251282169888233e-05,
#  'perkedup': 5.7820513561801455e-06,
#  'competitive': 0.0010581153981809666,
#  'compensation': 0.0013240897605652534,
#  'vibrant': 2.3128205424720582e-05,
#  'upbeat': 1.1564102712360291e-05,
#  'almost': 0.0006880641113854373,
#  'nonexistent': 0.00012720512983596321,
#  'performance': 0.0009656025764820843,
#  'expectation': 0.0004163076976449705,
#  'length': 1.7346154068540437e-05,
#  'spoil': 2.8910256780900728e-05,
#  'employeeson': 5.7820513561801455e-06,
#  'hand': 0.0005030384679876726,
#  'menial': 2.3128205424720582e-05,
#  'compare': 0.0003411410300146286,
#  'brainpower': 5.7820513561801455e-06,
#  'hire': 0.0012489230929349114,
#  'safety': 9.251282169888233e-05,
#  'net': 5.7820513561801455e-05,
#  'prevent': 8.673077034270219e-05,
#  'risk': 0.0003006666705213676,
#  'probably': 0.00024284615695956612,
#  'whole': 0.0002891025678090073,
#  'industry': 0.0011043718090304078,
#  'learning': 0.0007054102654539778,
#  'enthusiastic': 3.469230813708087e-05,
#  'technology': 0.004163076976449705,
#  'mediocre': 8.673077034270219e-05,
#  'join': 0.0005203846220562131,
#  'school': 0.00022550000289102567,
#  'product': 0.003052923116063117,
#  'top': 0.0009424743710573638,
#  'develop': 0.0010812436036056873,
#  'pm': 0.00031223077323372784,
#  'fundamental': 4.047435949326102e-05,
#  'multiple': 0.0007574487276595991,
#  'huge': 0.0005897692383303748,
#  'senior': 0.0005782051356180146,
#  'procedural': 1.1564102712360291e-05,
#  'become': 0.0008499615493584814,
#  'definitely': 0.0005897692383303748,
#  'coast': 8.673077034270219e-05,
#  'lack': 0.0008904359088517424,
#  'urgency': 1.7346154068540437e-05,
#  'balance': 0.004417487236121631,
#  'meal': 5.7820513561801455e-05,
#  'talented': 0.0006128974437550954,
#  'supportive': 0.0009077820629202829,
#  'frame': 4.047435949326102e-05,
#  'complete': 0.0006591538546045365,
#  'ticket': 0.00018502564339776466,
#  'rewarding': 0.0003411410300146286,
#  'ok': 0.0004567820571382315,
#  'demand': 0.00041052564628879035,
#  'worht': 5.7820513561801455e-06,
#  'toxic': 0.00018502564339776466,
#  'cash': 5.203846220562131e-05,
#  'ogo': 5.7820513561801455e-06,
#  'ppl': 5.7820513561801455e-05,
#  'manag': 5.7820513561801455e-06,
#  'short': 0.00046256410849441164,
#  'amount': 0.0005088205193438529,
#  'meet': 0.0013298718119214336,
#  'friend': 0.0003931794922202499,
#  'moon': 1.1564102712360291e-05,
#  'massage': 4.6256410849441164e-05,
#  'barely': 5.7820513561801455e-05,
#  'innovative': 0.0004914743652753124,
#  'consistently': 9.829487305506248e-05,
#  'promote': 0.0006302435978236359,
#  'bonus': 0.0006822820600292572,
#  'extra': 0.00022550000289102567,
#  'stadia': 1.1564102712360291e-05,
#  'quite': 0.000514602570700033,
#  'upset': 1.1564102712360291e-05,
#  'department': 0.0008210512925775807,
#  'rude': 4.047435949326102e-05,
#  'expect': 0.001353000017346154,
#  'removed': 5.7820513561801455e-06,
#  'ton': 0.000358487184083169,
#  'co': 0.0003295769273022683,
#  'room': 0.000636025649179816,
#  'home': 0.0014802051471821173,
#  'morale': 0.00023706410560338597,
#  'supervisor': 0.00021971795153484554,
#  'vision': 0.0003931794922202499,
#  'health': 0.0005319487247685734,
#  'dental': 7.51666676303419e-05,
#  'raise': 0.000595551289686555,
#  'napa': 1.1564102712360291e-05,
#  'valley': 0.00015611538661686392,
#  'winery': 5.7820513561801455e-06,
#  'offer': 0.0010176410386877057,
#  'wine': 1.7346154068540437e-05,
#  'plus': 0.00032379487594608815,
#  'something': 0.0009020000115641027,
#  'art': 8.094871898652204e-05,
#  'architecture': 0.00020815384882248524,
#  'garden': 1.7346154068540437e-05,
#  'view': 0.00026019231102810655,
#  'especially': 0.0005319487247685734,
#  'first': 0.0012200128361540108,
#  'want': 0.0022376538748417165,
#  'iconic': 1.1564102712360291e-05,
#  'beautiful': 7.51666676303419e-05,
#  'estate': 2.8910256780900728e-05,
#  'unforgettable': 1.1564102712360291e-05,
#  'country': 0.00022550000289102567,
#  'workgood': 8.094871898652204e-05,
#  'supporti': 1.7346154068540437e-05,
#  'honestly': 0.00010407692441124262,
#  'worth': 0.00026019231102810655,
#  'hard': 0.003532833378626069,
#  'skill': 0.002416897466883301,
#  'miss': 0.000318012824589908,
#  'lucky': 0.000277538465096647,
#  'remotely': 0.00033535897865844845,
#  'except': 0.0001792435920415845,
#  'mostly': 0.0005492948788371138,
#  'weak': 2.8910256780900728e-05,
#  'mixed': 4.6256410849441164e-05,
#  'ic': 2.8910256780900728e-05,
#  'many': 0.00437123082527219,
#  'report': 0.0006186794951112756,
#  'performancepromotion': 5.7820513561801455e-06,
#  'base': 0.0009598205251259041,
#  'ladder': 9.829487305506248e-05,
#  'mean': 0.00041052564628879035,
#  'little': 0.001150628219879849,
#  'invite': 2.8910256780900728e-05,
#  'bad': 0.0016999230987169629,
#  'leadership': 0.001034987192756246,
#  'behaviorsexcept': 5.7820513561801455e-06,
#  'wonderful': 0.0005435128274809337,
#  'perfect': 0.00015611538661686392,
#  'express': 6.360256491798161e-05,
#  'way': 0.001873384639402367,
#  'contrary': 1.1564102712360291e-05,
#  'social': 0.00021971795153484554,
#  'more': 5.7820513561801455e-06,
#  'extreme': 9.829487305506248e-05,
#  'national': 4.6256410849441164e-05,
#  'socialist': 5.7820513561801455e-06,
#  'begin': 0.00023706410560338597,
#  'spy': 1.7346154068540437e-05,
#  'upon': 0.00016767948932922423,
#  'anonymously': 1.1564102712360291e-05,
#  'retirement': 9.829487305506248e-05,
#  'end': 0.0009887307819068049,
#  'perform': 0.00046834615985059177,
#  'engage': 0.00018502564339776466,
#  'ever': 0.0010002948846191651,
#  'dream': 0.00014455128390450364,
#  'surely': 3.469230813708087e-05,
#  'achieve': 0.000358487184083169,
#  'awesome': 0.00079214103579668,
#  'period': 0.0002891025678090073,
#  'build': 0.001029205141400066,
#  'afterwards': 1.7346154068540437e-05,
#  'swe': 4.047435949326102e-05,
#  'intern': 0.0007863589844404998,
#  'week': 0.00079214103579668,
#  'host': 6.938461627416175e-05,
#  'groupmate': 5.7820513561801455e-06,
#  'push': 0.0005724230842618345,
#  'live': 0.0003700512867955293,
#  'cost': 0.0005030384679876726,
#  'coverage': 4.6256410849441164e-05,
#  'shuttlebike': 5.7820513561801455e-06,
#  'rental': 5.7820513561801455e-06,
#  'gym': 0.00032379487594608815,
#  'entertainment': 5.203846220562131e-05,
#  'hope': 0.00020815384882248524,
#  'return': 0.0001503333352606838,
#  'entire': 0.0003411410300146286,
#  'lifethere': 5.7820513561801455e-06,
#  'personality': 0.00010407692441124262,
#  'virtual': 0.0001387692325483235,
#  'internship': 0.0003411410300146286,
#  'belong': 4.6256410849441164e-05,
#  'developer': 0.001029205141400066,
#  'online': 0.00025441025967192643,
#  'orientation': 4.6256410849441164e-05,
#  'set': 0.0007458846249472388,
#  'break': 0.0003700512867955293,
#  'ill': 5.7820513561801455e-05,
#  'productive': 0.0008152692412214006,
#  'position': 0.0015033333526068378,
#  'cafeteria': 0.00018502564339776466,
#  'laundry': 2.3128205424720582e-05,
#  'sign': 9.829487305506248e-05,
#  'relocation': 2.3128205424720582e-05,
#  'lotthey': 5.7820513561801455e-06,
#  'emphasis': 0.00012720512983596321,
#  'learningthey': 5.7820513561801455e-06,
#  'comfortablework': 5.7820513561801455e-06,
#  'friendly': 0.00158428207159336,
#  'helpfulall': 5.7820513561801455e-06,
#  'dry': 2.8910256780900728e-05,
#  'cleaning': 1.7346154068540437e-05,
#  'downside': 0.00016767948932922423,
#  'user': 0.0004567820571382315,
#  'collect': 5.203846220562131e-05,
#  'datum': 0.00079214103579668,
#  'check': 0.0002833205164528271,
#  'plan': 0.0007690128303719594,
#  'enjoyable': 0.001555371814812459,
#  'impactful': 8.673077034270219e-05,
#  'reach': 0.00024284615695956612,
#  'nothing': 0.0006302435978236359,
#  'impossible': 0.00013298718119214334,
#  'mindset': 7.51666676303419e-05,
#  'handle': 0.00033535897865844845,
#  'account': 0.0002891025678090073,
#  'catch': 0.00016189743797304407,
#  'manipulate': 4.047435949326102e-05,
#  'statistic': 2.3128205424720582e-05,
#  'force': 0.0004220897490011506,
#  'traumatic': 5.7820513561801455e-06,
#  'collaboration': 0.0003816153895078896,
#  'across': 0.0006186794951112756,
#  'engaging': 1.1564102712360291e-05,
#  'addition': 0.00014455128390450364,
#  'campus': 0.0005203846220562131,
#  'respectful': 8.673077034270219e-05,
#  'fund': 7.51666676303419e-05,
#  'generally': 0.00048569231391913225,
#  'forward': 0.0003931794922202499,
#  'careerpro': 5.7820513561801455e-06,
#  'may': 0.0009656025764820843,
#  'itcon': 5.7820513561801455e-06,
#  'large': 0.0015322436093877386,
#  'opaque': 5.7820513561801455e-06,
#  'difference': 0.00018502564339776466,
#  'understand': 0.0007343205222348785,
#  'likely': 0.0001503333352606838,
#  'niche': 2.3128205424720582e-05,
#  'less': 0.0008846538574955623,
#  'llc': 5.7820513561801455e-06,
#  'american': 9.251282169888233e-05,
#  'multinational': 6.938461627416175e-05,
#  'specialize': 4.047435949326102e-05,
#  'internetrelated': 5.7820513561801455e-06,
#  'service': 0.0013298718119214336,
#  'include': 0.0007458846249472388,
#  'advertising': 2.3128205424720582e-05,
#  'search': 0.0001503333352606838,
#  'engine': 7.51666676303419e-05,
#  'cloud': 0.000716974368166338,
#  'compute': 8.094871898652204e-05,
#  'hardware': 0.0006071153923989153,
#  'former': 0.00011564102712360291,
#  'operation': 0.00020237179746630509,
#  'atlanta': 1.1564102712360291e-05,
#  'gapositive': 5.7820513561801455e-06,
#  'outlookno': 5.7820513561801455e-06,
#  'opinion': 0.00017346154068540438,
#  'ceoi': 5.7820513561801455e-06,
#  'yearprosthe': 5.7820513561801455e-06,
#  'dress': 9.829487305506248e-05,
#  'casual': 0.0001503333352606838,
#  'cubicle': 9.251282169888233e-05,
#  'quiet': 8.673077034270219e-05,
#  'workthe': 5.7820513561801455e-05,
#  'security': 0.0011621923225922093,
#  'friendsconsthe': 5.7820513561801455e-06,
#  'datacenter': 2.3128205424720582e-05,
#  'never': 0.0012951795037843526,
#  'enough': 0.0007343205222348785,
#  'toolsyou': 1.1564102712360291e-05,
#  'completely': 0.0003064487218775477,
#  'should': 2.8910256780900728e-05,
#  'loose': 5.7820513561801455e-05,
#  'posttrainigi': 5.7820513561801455e-06,
#  'cry': 1.7346154068540437e-05,
#  'times': 5.203846220562131e-05,
#  'floor': 0.00012142307847978306,
#  'documentation': 0.0001908076947539448,
#  'intranet': 2.8910256780900728e-05,
#  'employeesthey': 1.1564102712360291e-05,
#  'phd': 2.8910256780900728e-05,
#  'itligence': 9.829487305506248e-05,
#  'hratlanta': 5.7820513561801455e-06,
#  'neglect': 1.1564102712360291e-05,
#  'redheade': 5.7820513561801455e-06,
#  'stepchild': 5.7820513561801455e-06,
#  'data': 0.000358487184083169,
#  'centercan': 5.7820513561801455e-06,
#  'somewhat': 0.00014455128390450364,
#  'political': 0.000277538465096647,
#  'involve': 0.0006071153923989153,
#  'politic': 0.0006880641113854373,
#  'anywhere': 0.00018502564339776466,
#  'memegen': 5.7820513561801455e-06,
#  'internal': 0.0007516666763034189,
#  'mailing': 5.7820513561801455e-06,
#  'list': 0.00011564102712360291,
#  'neutral': 5.7820513561801455e-06,
#  'manner': 0.00011564102712360291,
#  'pretend': 3.469230813708087e-05,
#  'side': 0.0006071153923989153,
#  'correct': 6.938461627416175e-05,
#  'rather': 0.0004220897490011506,
#  'belief': 2.8910256780900728e-05,
#  'll': 0.00045100000578205134,
#  'alrighti': 5.7820513561801455e-06,
#  'sweat': 3.469230813708087e-05,
#  'bring': 0.0004220897490011506,
#  'spillproof': 5.7820513561801455e-06,
#  'tumbler': 5.7820513561801455e-06,
#  'clear': 0.00041052564628879035,
#  'drink': 0.00016189743797304407,
#  'container': 1.1564102712360291e-05,
#  'dc': 1.1564102712360291e-05,
#  'floorthe': 5.7820513561801455e-06,
#  'training': 0.0016421025851551614,
#  'protocol': 5.7820513561801455e-05,
#  'conflict': 5.7820513561801455e-05,
#  'speed': 0.00012142307847978306,
#  'repair': 4.6256410849441164e-05,
#  'must': 0.0003295769273022683,
#  'accomplish': 0.0002139359001786654,
#  'eg': 3.469230813708087e-05,
#  'shortcut': 1.7346154068540437e-05,
#  'wear': 8.673077034270219e-05,
#  'globe': 5.7820513561801455e-05,
#  'battery': 2.3128205424720582e-05,
#  'swap': 1.7346154068540437e-05,
#  'even': 0.0016305384824428012,
#  'safe': 0.0001792435920415845,
#  'fire': 0.000318012824589908,
#  'glove': 1.1564102712360291e-05,
#  'inspector': 1.1564102712360291e-05,
#  'onsite': 0.00017346154068540438,
#  'show': 0.00040474359493261017,
#  'unsafe': 1.1564102712360291e-05,
#  'atmore': 5.7820513561801455e-06,
#  'twice': 0.00011564102712360291,
#  'itx': 5.7820513561801455e-06,
#  'specification': 0.00011564102712360291,
#  'narrowly': 1.1564102712360291e-05,
#  'define': 0.0002139359001786654,
#  'worry': 9.251282169888233e-05,
#  'attend': 0.0001908076947539448,
#  'meeting': 0.0014975513012506576,
#  'regular': 0.00032379487594608815,
#  'hourly': 4.6256410849441164e-05,
#  'equal': 5.7820513561801455e-05,
#  'stock': 0.00047991026256295207,
#  'obviously': 4.047435949326102e-05,
#  'participate': 9.251282169888233e-05,
#  'group': 0.0017461795095664039,
#  'mind': 0.0003527051327269889,
#  'timer': 5.7820513561801455e-05,
#  'yr': 4.6256410849441164e-05,
#  'contract': 0.0008673077034270218,
#  'prospect': 6.360256491798161e-05,
#  'conversion': 4.6256410849441164e-05,
#  'either': 0.0003527051327269889,
#  'resume': 0.0001908076947539448,
#  'btw': 1.1564102712360291e-05,
#  'neck': 2.3128205424720582e-05,
#  'deep': 9.829487305506248e-05,
#  'workingsitte': 5.7820513561801455e-06,
#  'add': 0.000277538465096647,
#  'title': 9.829487305506248e-05,
#  'mentor': 0.00037583333815170944,
#  'summer': 0.00013298718119214334,
#  'xwiki': 5.7820513561801455e-06,
#  'wellknown': 1.1564102712360291e-05,
#  'name': 0.00014455128390450364,
#  'burocracy': 5.7820513561801455e-06,
#  'exciting': 0.0005377307761247536,
#  'kickstart': 5.7820513561801455e-06,
#  'cv': 5.7820513561801455e-06,
#  'easy': 0.0011332820658113084,
#  'futurerequire': 5.7820513561801455e-06,
#  'focus': 0.0015611538661686392,
#  'fulfilling': 2.8910256780900728e-05,
#  'wise': 0.00012720512983596321,
#  'higher': 1.7346154068540437e-05,
#  'effective': 0.00012720512983596321,
#  'stay': 0.00079214103579668,
#  'lock': 4.047435949326102e-05,
#  'proprietary': 4.047435949326102e-05,
#  'requirement': 0.0005435128274809337,
#  'number': 0.0007343205222348785,
#  'careerwe': 5.7820513561801455e-06,
#  'scope': 0.00027175641374046686,
#  'improvise': 1.1564102712360291e-05,
#  'difficulty': 4.047435949326102e-05,
#  'process': 0.0016363205337989813,
#  'acquire': 0.00027175641374046686,
#  'modifying': 1.1564102712360291e-05,
#  'exist': 0.0003064487218775477,
#  'knowledge': 0.0010118589873315254,
#  'behavior': 9.251282169888233e-05,
#  'preference': 2.8910256780900728e-05,
#  'possess': 2.3128205424720582e-05,
#  'human': 0.0001503333352606838,
#  'animal': 5.7820513561801455e-06,
#  'machine': 0.000277538465096647,
#  'evidence': 4.047435949326102e-05,
#  'certain': 0.00023706410560338597,
#  'plant': 2.8910256780900728e-05,
#  'competition': 0.00021971795153484554,
#  'everyone': 0.0014917692498944775,
#  'situationit': 5.7820513561801455e-06,
#  'follow': 0.0003816153895078896,
#  'adbise': 5.7820513561801455e-06,
#  'god': 5.203846220562131e-05,
#  'thank': 0.0001387692325483235,
#  'suppose': 0.00013298718119214334,
#  'meetingsother': 5.7820513561801455e-06,
#  'micro': 0.0001792435920415845,
#  'firm': 0.00011564102712360291,
#  'highly': 0.0008094871898652203,
#  'creativity': 9.251282169888233e-05,
#  'drive': 0.0007979230871528601,
#  'true': 0.00025441025967192643,
#  'vary': 0.0003411410300146286,
#  'different': 0.0024978461858698228,
#  'hour': 0.002341730799252959,
#  'try': 0.0013761282227708746,
#  'soften': 5.7820513561801455e-06,
#  'blow': 2.3128205424720582e-05,
#  'open': 0.001029205141400066,
#  'scheduleadvancement': 5.7820513561801455e-06,
#  'stuff': 0.0002659743623842867,
#  'middle': 0.00027175641374046686,
#  'layer': 0.00022550000289102567,
#  'executive': 0.0003700512867955293,
#  'gigantic': 1.7346154068540437e-05,
#  'book': 8.673077034270219e-05,
#  'vs': 6.360256491798161e-05,
#  'talent': 0.00045100000578205134,
#  'org': 0.0002833205164528271,
#  'goalsthe': 5.7820513561801455e-06,
#  'nonstop': 3.469230813708087e-05,
#  'bus': 9.829487305506248e-05,
#  'director': 0.00011564102712360291,
#  'sexually': 5.7820513561801455e-06,
#  'harass': 4.6256410849441164e-05,
#  'still': 0.0012257948875101909,
#  'hr': 0.0002659743623842867,
#  'seek': 0.0002139359001786654,
#  'vote': 1.1564102712360291e-05,
#  'woman': 8.673077034270219e-05,
#  'leader': 0.0005377307761247536,
#  'whereas': 3.469230813708087e-05,
#  'lay': 0.0007343205222348785,
#  'leave': 0.0015322436093877386,
#  'got': 0.00027175641374046686,
#  'cancel': 9.251282169888233e-05,
#  'reorg': 8.094871898652204e-05,
#  'guy': 0.00016189743797304407,
#  'super': 0.00031223077323372784,
#  'itligent': 0.00023128205424720582,
#  'fast': 0.0010696795008933268,
#  'pace': 0.0009424743710573638,
#  'unlimited': 9.829487305506248e-05,
#  'foster': 0.00012142307847978306,
#  'clearthe': 5.7820513561801455e-06,
#  'realistic': 1.1564102712360291e-05,
#  'completion': 9.251282169888233e-05,
#  'task': 0.0010985897576742277,
#  'grasp': 4.047435949326102e-05,
#  'quickly': 0.0004220897490011506,
#  'positive': 0.0005492948788371138,
#  'advantage': 0.00016189743797304407,
#  'silent': 5.7820513561801455e-06,
#  'hundred': 5.7820513561801455e-05,
#  'thousand': 7.51666676303419e-05,
#  'single': 0.00020237179746630509,
#  'finish': 0.00025441025967192643,
#  'two': 0.0006938461627416175,
#  'course': 0.0003006666705213676,
#  'largely': 5.7820513561801455e-05,
#  'receive': 0.0003527051327269889,
#  'besides': 5.7820513561801455e-05,
#  'phenomenal': 3.469230813708087e-05,
#  'loon': 5.7820513561801455e-06,
#  'lab': 0.0001792435920415845,
#  'network': 0.0005897692383303748,
#  'mix': 8.094871898652204e-05,
#  'previous': 0.00016767948932922423,
#  'might': 0.0004163076976449705,
#  'bed': 1.7346154068540437e-05,
#  'bug': 0.00023706410560338597,
#  'close': 0.00025441025967192643,
#  'present': 0.0001792435920415845,
#  'tv': 2.3128205424720582e-05,
#  'xboxes': 5.7820513561801455e-06,
#  'ps': 5.7820513561801455e-06,
#  'everything': 0.0007574487276595991,
#  'chill': 7.51666676303419e-05,
#  'unite': 1.1564102712360291e-05,
#  'states': 5.7820513561801455e-05,
#  'term': 0.0006707179573168969,
#  'market': 0.000676500008673077,
#  'capitalization': 5.7820513561801455e-06,
#  'bicycle': 2.3128205424720582e-05,
#  'electric': 4.047435949326102e-05,
#  'car': 4.6256410849441164e-05,
#  'gaming': 1.1564102712360291e-05,
#  'center': 0.00046834615985059177,
#  'organic': 1.7346154068540437e-05,
#  'ecofriendly': 5.7820513561801455e-06,
#  'furnishing': 5.7820513561801455e-06,
#  'constantly': 0.0006533718032483564,
#  'wellbee': 5.203846220562131e-05,
#  'itrs': 2.3128205424720582e-05,
#  'organization': 0.0009482564224135439,
#  'terminology': 1.1564102712360291e-05,
#  'companyeverything': 5.7820513561801455e-06,
#  'managedmanager': 5.7820513561801455e-06,
#  'naturetraining': 5.7820513561801455e-06,
#  'wella': 5.7820513561801455e-06,
#  'fresher': 4.047435949326102e-05,
#  'decent': 0.0005030384679876726,
#  'perf': 1.1564102712360291e-05,
#  'frequently': 0.0001503333352606838,
#  'assignment': 0.0002891025678090073,
#  'vague': 4.047435949326102e-05,
#  'torture': 5.7820513561801455e-06,
#  'ambiguous': 4.047435949326102e-05,
#  'deciding': 5.7820513561801455e-06,
#  'guidancefeedbacksupport': 5.7820513561801455e-06,
#  'function': 0.000277538465096647,
#  'dedicated': 0.00016189743797304407,
#  'player': 0.00010407692441124262,
#  'backend': 5.7820513561801455e-05,
#  'keen': 4.047435949326102e-05,
#  'lesson': 2.8910256780900728e-05,
#  'stack': 0.0003411410300146286,
#  'surround': 0.00013298718119214334,
#  'extremely': 0.0006880641113854373,
#  'comfortable': 0.00020237179746630509,
#  'greatand': 5.7820513561801455e-06,
#  'pager': 2.8910256780900728e-05,
#  'mention': 0.00011564102712360291,
#  'countedthe': 5.7820513561801455e-06,
#  'groundbreake': 5.7820513561801455e-06,
#  'problem': 0.00119688463072929,
#  'debt': 1.7346154068540437e-05,
#  'resource': 0.0009656025764820843,
#  'tend': 0.00025441025967192643,
#  'throw': 0.00018502564339776466,
#  'critical': 0.00017346154068540438,
#  'note': 4.6256410849441164e-05,
#  'average': 0.0004914743652753124,
#  'merely': 1.7346154068540437e-05,
#  'greatness': 1.7346154068540437e-05,
#  'embarrassing': 5.7820513561801455e-06,
#  'codetheir': 5.7820513561801455e-06,
#  'siginficant': 5.7820513561801455e-06,
#  'drawback': 4.047435949326102e-05,
#  'firstlevel': 5.7820513561801455e-06,
#  'random': 4.047435949326102e-05,
#  'skillbut': 5.7820513561801455e-06,
#  'beware': 2.8910256780900728e-05,
#  'aggressively': 1.1564102712360291e-05,
#  'liberal': 5.7820513561801455e-06,
#  'internally': 0.00022550000289102567,
#  'externally': 2.8910256780900728e-05,
#  'conservative': 3.469230813708087e-05,
#  'head': 0.0003064487218775477,
#  'lead': 0.0012257948875101909,
#  'unbearable': 2.3128205424720582e-05,
#  'condition': 9.251282169888233e-05,
#  'pressure': 0.0005435128274809337,
#  'phone': 0.0003527051327269889,
#  'fix': 0.000358487184083169,
#  'peacefully': 5.7820513561801455e-06,
#  'lifeif': 5.7820513561801455e-06,
#  'chance': 0.0006128974437550954,
#  'glad': 5.7820513561801455e-05,
#  'daily': 0.0006533718032483564,
#  'implement': 0.00047991026256295207,
#  'concept': 0.0002139359001786654,
#  'assist': 0.0001792435920415845,
#  'solve': 0.0005839871869741947,
#  'customer': 0.0030008846538574956,
#  'arrogance': 5.7820513561801455e-06,
#  'measurement': 2.3128205424720582e-05,
#  'mistake': 6.360256491798161e-05,
#  'understood': 5.7820513561801455e-06,
#  'happen': 0.0005088205193438529,
#  'repeatedly': 1.7346154068540437e-05,
#  'appropriately': 1.1564102712360291e-05,
#  'amenity': 9.829487305506248e-05,
#  'publicize': 5.7820513561801455e-06,
#  'imagine': 9.829487305506248e-05,
#  'itvery': 5.7820513561801455e-06,
#  'projectslearned': 5.7820513561801455e-06,
#  'projectsamaze': 5.7820513561801455e-06,
#  'happy': 0.0006013333410427352,
#  'sick': 0.00016767948932922423,
#  'dumb': 1.1564102712360291e-05,
#  'mark': 4.047435949326102e-05,
#  'sound': 5.203846220562131e-05,
#  'rightover': 5.7820513561801455e-06,
#  'successful': 0.000358487184083169,
#  'withoutstande': 5.7820513561801455e-06,
#  'benefitsfriendly': 5.7820513561801455e-06,
#  'environmenta': 1.1564102712360291e-05,
#  'dynamic': 0.00020237179746630509,
#  'placeminimum': 5.7820513561801455e-06,
#  'exhaust': 1.1564102712360291e-05,
#  'unnecessary': 5.7820513561801455e-05,
#  'cooperative': 8.673077034270219e-05,
#  'resourceful': 2.8910256780900728e-05,
#  'encourage': 0.0008383974466461211,
#  'timeline': 8.094871898652204e-05,
#  'enjoyed': 8.094871898652204e-05,
#  'guilty': 1.1564102712360291e-05,
#  'complaining': 5.7820513561801455e-06,
#  'd': 0.000358487184083169,
#  'instead': 0.000358487184083169,
#  'frustrating': 0.0001908076947539448,
#  'startup': 0.00024862820831574625,
#  'getting': 0.00023128205424720582,
#  'stateoftheart': 2.3128205424720582e-05,
#  'rewrite': 2.3128205424720582e-05,
#  'standard': 0.0006186794951112756,
#  'style': 0.00031223077323372784,
#  'library': 6.360256491798161e-05,
#  'opposite': 5.203846220562131e-05,
#  'freedom': 0.00033535897865844845,
#  'monolithic': 1.1564102712360291e-05,
#  'codebase': 1.7346154068540437e-05,
#  'readability': 5.7820513561801455e-06,
#  'programming': 0.000277538465096647,
#  'language': 0.00017346154068540438,
#  'folk': 0.0003295769273022683,
#  'buddy': 2.3128205424720582e-05,
#  'review': 0.0013009615551405327,
#  'handcuff': 5.7820513561801455e-06,
#  'young': 0.00033535897865844845,
#  'workforce': 0.0001908076947539448,
#  'privileged': 1.7346154068540437e-05,
#  'background': 0.00025441025967192643,
#  'materialistic': 5.7820513561801455e-06,
#  'gets': 6.938461627416175e-05,
#  'weird': 5.203846220562131e-05,
#  'acquisition': 0.00023706410560338597,
#  'increasingly': 5.7820513561801455e-05,
#  'skip': 5.203846220562131e-05,
#  'interview': 0.00022550000289102567,
#  'system': 0.0016305384824428012,
#  'wellwritten': 5.7820513561801455e-06,
#  'severe': 4.047435949326102e-05,
#  'nih': 5.7820513561801455e-06,
#  'developmental': 1.1564102712360291e-05,
#  'slowness': 5.7820513561801455e-06,
#  'outdate': 2.8910256780900728e-05,
#  'reactjs': 5.7820513561801455e-06,
#  'dominant': 1.1564102712360291e-05,
#  'framework': 0.0001908076947539448,
#  'outside': 0.0005319487247685734,
#  'compete': 0.00024284615695956612,
#  'angular': 3.469230813708087e-05,
#  'frontend': 7.51666676303419e-05,
#  'seriously': 8.673077034270219e-05,
#  'javascript': 0.00010985897576742277,
#  'tolerate': 4.047435949326102e-05,
#  'real': 0.0005666410329056542,
#  'disparate': 3.469230813708087e-05,
#  'improvement': 0.00033535897865844845,
#  'implementation': 0.00027175641374046686,
#  'equip': 2.8910256780900728e-05,
#  'spm': 5.7820513561801455e-06,
#  'solution': 0.0006013333410427352,
#  'accelerate': 2.8910256780900728e-05,
#  'okraction': 5.7820513561801455e-06,
#  'metric': 0.00019658974611012496,
#  'additional': 0.00012720512983596321,
#  'visibility': 0.00010407692441124262,
#  ...}

# %%
len_tok
# Out:
# 172949

# %%
len(global_key_mapping)
# Out:
# 13519

# %%
# Retrieve key-value pairs with the highest 5 values
highest_pairs = sorted(global_key_mapping.items(), key=lambda x: x[1], reverse=True)[:5]

print("Key-value pairs with the highest 5 values:")
for pair in highest_pairs:
    print(pair)
# Out:
# Key-value pairs with the highest 5 values:
# ('work', 0.045435359556863585)
# ('good', 0.018837923318434913)
# ('great', 0.015495897634562791)
# ('company', 0.014963948909794217)
# ('team', 0.01146580783930523)

# %% [markdown]
# ## Get entropy for each sample

# %%
CS_Reviews_Final['tok'] = CS_Reviews_Final['lemmatized'].apply(word_tokenize)
CS_Reviews_Final['bow'] = CS_Reviews_Final['tok'].apply(Counter)
CS_Reviews_Final['num_unique_word'] = CS_Reviews_Final['bow'].apply(len)
CS_Reviews_Final['key'] = CS_Reviews_Final['bow'].apply(lambda l:list(l.keys()))
CS_Reviews_Final['prob'] = [{k:v for k,v in global_key_mapping.items() if k in x} for x in CS_Reviews_Final['key']]
CS_Reviews_Final['entropy'] = CS_Reviews_Final.apply(lambda x: entropy(x.bow, x.prob), axis=1)
CS_Reviews_Final
# Out:
#                                                   title  \
# 0                                             Dream job
# 1     Worked as a contractor software engineer, work...
# 2                          Productive and fun workplace
# 3                            Great company to work for!
# 4                                        Best Workplace
# ...                                                 ...
# 7056                                                Ibm
# 7057                                            5 stars
# 7058                                      Great company
# 7059            Great WLB, pay and technical challenges
# 7060                  Best company I've ever worked for
#
#                                                status  \
# 0                 Software Engineer(Current Employee)
# 1       Software Engineer Contractor(Former Employee)
# 2                  Software Engineer(Former Employee)
# 3      Quality Assurance Specialist(Current Employee)
# 4                 Software Engineer(Current Employee)
# ...                                               ...
# 7056             Delivery Architect(Current Employee)
# 7057  Sr. Technical Program Manager(Current Employee)
# 7058              Software Engineer(Current Employee)
# 7059              Software Engineer(Current Employee)
# 7060         Staff Software Engineer(Former Employee)
#
#                                                    pros  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7056                                                NaN
# 7057                                                NaN
# 7058                                                NaN
# 7059                                                NaN
# 7060  Excellent culture. Free food. Great coffee and...
#
#                                           cons  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 7056                                       NaN
# 7057                                       NaN
# 7058                                       NaN
# 7059                                       NaN
# 7060  Work could be less challenging at times.
#
#                                                  review  rating  \
# 0     This is one of the best place to work in the w...     5.0
# 1     Worked as a contractor software engineer, work...     5.0
# 2     It was a fun and interesting experience. Lots ...     5.0
# 3     One of the best companies to work for overall....     5.0
# 4     Google is a great work place. They pay well an...     5.0
# ...                                                 ...     ...
# 7056  I’ve been with IBM for many years of my career...     1.0
# 7057  What is the best part of working at the compan...     5.0
# 7058  LinkedIn's food is great. There is a InDay eve...     5.0
# 7059  Great pay, tons of time off.Food is top notch,...     5.0
# 7060  I got to work with talented and passionate col...     5.0
#
#                                        processed_review  \
# 0     this is one of the best place to work in the w...
# 1     worked as a contractor software engineer work ...
# 2     it was a fun and interesting experience lots o...
# 3     one of the best companies to work for overall ...
# 4     it is a great work place they pay well and res...
# ...                                                 ...
# 7056  ive been with it for many years of my career i...
# 7057  what is the best part of working at the compan...
# 7058  its food is great there is a inday every month...
# 7059  great pay tons of time offfood is top notch pr...
# 7060  i got to work with talented and passionate col...
#
#                                                 wo_stop  \
# 0     one best place work world couldnt ask culture ...
# 1     worked contractor software engineer work time ...
# 2     fun interesting experience lots handson truly ...
# 3     one best companies work overall stable company...
# 4     great work place pay well respect employees te...
# ...                                                 ...
# 7056  ive many years career facet every step done la...
# 7057  best part working companythe culturewhat stres...
# 7058  food great inday every month lot learn culture...
# 7059  great pay tons time offfood top notch probably...
# 7060  got work talented passionate colleagues valued...
#
#                                              lemmatized  total_word_num  \
# 0     one good place work world could not ask cultur...              19
# 1     work contractor software engineer work time fl...              17
# 2     fun interesting experience lot handson truly l...              13
# 3     one good company work overall stable company p...              16
# 4     great work place pay well respect employee tea...              24
# ...                                                 ...             ...
# 7056  I ve many year career facet every step do layo...              27
# 7057  good part work companythe culturewhat stressfu...              17
# 7058  food great inday every month lot learn culture...              13
# 7059  great pay ton time offfood top notch probably ...              22
# 7060  get work talented passionate colleague value e...              22
#
#       raw_word_count                                                tok  \
# 0                 34  [one, good, place, work, world, could, not, as...
# 1                 26  [work, contractor, software, engineer, work, t...
# 2                 29  [fun, interesting, experience, lot, handson, t...
# 3                 32  [one, good, company, work, overall, stable, co...
# 4                 51  [great, work, place, pay, well, respect, emplo...
# ...              ...                                                ...
# 7056              58  [I, ve, many, year, career, facet, every, step...
# 7057              34  [good, part, work, companythe, culturewhat, st...
# 7058              30  [food, great, inday, every, month, lot, learn,...
# 7059              31  [great, pay, ton, time, offfood, top, notch, p...
# 7060              38  [get, work, talented, passionate, colleague, v...
#
#                                                     bow  num_unique_word  \
# 0     {'one': 1, 'good': 1, 'place': 1, 'work': 2, '...               18
# 1     {'work': 2, 'contractor': 3, 'software': 1, 'e...               14
# 2     {'fun': 1, 'interesting': 1, 'experience': 2, ...               11
# 3     {'one': 1, 'good': 1, 'company': 2, 'work': 1,...               15
# 4     {'great': 1, 'work': 2, 'place': 2, 'pay': 1, ...               20
# ...                                                 ...              ...
# 7056  {'I': 1, 've': 1, 'many': 1, 'year': 1, 'caree...               25
# 7057  {'good': 1, 'part': 2, 'work': 3, 'companythe'...               14
# 7058  {'food': 2, 'great': 1, 'inday': 1, 'every': 1...               12
# 7059  {'great': 1, 'pay': 1, 'ton': 1, 'time': 1, 'o...               22
# 7060  {'get': 1, 'work': 2, 'talented': 1, 'passiona...               18
#
#                                                     key  \
# 0     [one, good, place, work, world, could, not, as...
# 1     [work, contractor, software, engineer, time, f...
# 2     [fun, interesting, experience, lot, handson, t...
# 3     [one, good, company, work, overall, stable, pr...
# 4     [great, work, place, pay, well, respect, emplo...
# ...                                                 ...
# 7056  [I, ve, many, year, career, facet, every, step...
# 7057  [good, part, work, companythe, culturewhat, st...
# 7058  [food, great, inday, every, month, lot, learn,...
# 7059  [great, pay, ton, time, offfood, top, notch, p...
# 7060  [get, work, talented, passionate, colleague, v...
#
#                                                    prob   entropy
# 0     {'one': 0.003810371843722716, 'good': 0.018837...  0.849380
# 1     {'work': 0.045435359556863585, 'contractor': 0...  0.679704
# 2     {'work': 0.045435359556863585, 'fun': 0.002578...  0.589490
# 3     {'one': 0.003810371843722716, 'good': 0.018837...  0.818592
# 4     {'good': 0.018837923318434913, 'place': 0.0096...  1.214855
# ...                                                 ...       ...
# 7056  {'place': 0.009627115508039942, 'work': 0.0454...  0.602547
# 7057  {'good': 0.018837923318434913, 'work': 0.04543...  0.922879
# 7058  {'good': 0.018837923318434913, 'culture': 0.00...  0.429123
# 7059  {'good': 0.018837923318434913, 'time': 0.00762...  0.484396
# 7060  {'good': 0.018837923318434913, 'work': 0.04543...  0.854449
#
# [7061 rows x 17 columns]

# %% [markdown]
# # Save Processed Data

# %%
columns_to_exclude = ['tok', 'bow', 'key', 'prob']  # Replace with the actual column names you want to exclude
selected_columns = CS_Reviews_Final.drop(columns=columns_to_exclude)
selected_columns.to_csv("Reviews_complexity.csv")
